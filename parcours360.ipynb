# %%
import shutil
import os
import sys

# Définir le dossier source et la destination zip
dossier_source = "/data/FCP10/Donnees/MC/explo/FCP10_MLCDP_WAX647/code/Prod/SEGPOTDYN"
fichier_zip_destination = "/mnt/FCP10DTWH/adam.zip"

# Créer une archive zip de tout le dossier
shutil.make_archive(
    base_name=fichier_zip_destination.replace('.zip', ''),  # Chemin sans extension
    format='zip',
    root_dir=dossier_source
)

print(f"Dossier exporté avec succès vers : {fichier_zip_destination}")
# Out:
# Dossier exporté avec succès vers : /mnt/FCP10DTWH/adam.zip

# %%
# %run run.py
# Out:
# 2025-12-22 14:07:24 - advanced_pipeline - INFO - Logger advanced_pipeline configuré - Fichier: /data/FCP10/Donnees/MC/explo/FCP10_MLCDP_WAX647/code/Prod/SEGPOTDYN/logs/advanced_pipeline_20251222.log
# 2025-12-22 14:07:24 - advanced_pipeline - INFO - AdvancedPipeline initialisé - Mode: prod, Clustering: stratifie
# 2025-12-22 14:07:24 - advanced_pipeline - INFO - Force retrain: False
# 2025-12-22 14:07:24 - advanced_pipeline - INFO - === DÉMARRAGE PIPELINE AVANCÉ ===
# 2025-12-22 14:07:24 - advanced_pipeline - INFO - Étape 1: Extraction données
# 2025-12-22 14:07:24 - data_extractor - INFO - Logger data_extractor configuré - Fichier: /data/FCP10/Donnees/MC/explo/FCP10_MLCDP_WAX647/code/Prod/SEGPOTDYN/logs/data_extractor_20251222.log
# 2025-12-22 14:07:24 - data_extractor - INFO - DataExtractor initialisé - Cache: False
# 2025-12-22 14:07:24 - data_extractor - INFO - Début extraction complète
# 2025-12-22 14:07:24 - data_extractor - INFO - Extraction données socles depuis la base
# ...
